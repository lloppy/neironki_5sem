# %% [markdown]
# <a href="https://colab.research.google.com/github/lloppy/neironki_5sem/blob/main/titanic_%D0%BD%D1%83_%D1%82%D0%B0%D0%BA%D0%B0%D1%8F_%D1%81%D0%B5%D0%B1%D0%B5_%D0%B2%D0%B5%D1%80%D1%81%D0%B8%D1%8F_0_82_accuracy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df = pd.read_csv('/content/Titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (891, 12)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].fillna(df['Age'].mean(), inplace=True)
# Out:
# <ipython-input-28-7ee7fe972bc2>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(), inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
categorical_cols = df.select_dtypes(include=['object']).columns
label_encoders = {}

# %%
categorical_cols
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
for col in categorical_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

# %%
df
# Out:
#      PassengerId  Survived  Pclass  Name  Sex        Age  SibSp  Parch  \
# 0              1         0       3   108    1  22.000000      1      0
# 1              2         1       1   190    0  38.000000      1      0
# 2              3         1       3   353    0  26.000000      0      0
# 3              4         1       1   272    0  35.000000      1      0
# 4              5         0       3    15    1  35.000000      0      0
# ..           ...       ...     ...   ...  ...        ...    ...    ...
# 886          887         0       2   548    1  27.000000      0      0
# 887          888         1       1   303    0  19.000000      0      0
# 888          889         0       3   413    0  29.699118      1      2
# 889          890         1       1    81    1  26.000000      0      0
# 890          891         0       3   220    1  32.000000      0      0
#
#      Ticket     Fare  Cabin  Embarked
# 0       523   7.2500    147         2
# 1       596  71.2833     81         0
# 2       669   7.9250    147         2
# 3        49  53.1000     55         2
# 4       472   8.0500    147         2
# ..      ...      ...    ...       ...
# 886     101  13.0000    147         2
# 887      14  30.0000     30         2
# 888     675  23.4500    147         2
# 889       8  30.0000     60         0
# 890     466   7.7500    147         1
#
# [891 rows x 12 columns]

# %%
df_copy = df.copy()
df_copy
# Out:
#      PassengerId  Survived  Pclass  Name  Sex        Age  SibSp  Parch  \
# 0              1         0       3   108    1  22.000000      1      0
# 1              2         1       1   190    0  38.000000      1      0
# 2              3         1       3   353    0  26.000000      0      0
# 3              4         1       1   272    0  35.000000      1      0
# 4              5         0       3    15    1  35.000000      0      0
# ..           ...       ...     ...   ...  ...        ...    ...    ...
# 886          887         0       2   548    1  27.000000      0      0
# 887          888         1       1   303    0  19.000000      0      0
# 888          889         0       3   413    0  29.699118      1      2
# 889          890         1       1    81    1  26.000000      0      0
# 890          891         0       3   220    1  32.000000      0      0
#
#      Ticket     Fare  Cabin  Embarked
# 0       523   7.2500    147         2
# 1       596  71.2833     81         0
# 2       669   7.9250    147         2
# 3        49  53.1000     55         2
# 4       472   8.0500    147         2
# ..      ...      ...    ...       ...
# 886     101  13.0000    147         2
# 887      14  30.0000     30         2
# 888     675  23.4500    147         2
# 889       8  30.0000     60         0
# 890     466   7.7500    147         1
#
# [891 rows x 12 columns]

# %% [markdown]
# Modeling

# %%
# Fare - Стоимость билета
# SibSp - Количество братьев/сестер/супругов на борту
# Parch - Количество родителей/детей на борту

# %%
df.drop(columns=['PassengerId', 'Name', "Cabin"], inplace=True)
df
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch  Ticket     Fare  Embarked
# 0           0       3    1  22.000000      1      0     523   7.2500         2
# 1           1       1    0  38.000000      1      0     596  71.2833         0
# 2           1       3    0  26.000000      0      0     669   7.9250         2
# 3           1       1    0  35.000000      1      0      49  53.1000         2
# 4           0       3    1  35.000000      0      0     472   8.0500         2
# ..        ...     ...  ...        ...    ...    ...     ...      ...       ...
# 886         0       2    1  27.000000      0      0     101  13.0000         2
# 887         1       1    0  19.000000      0      0      14  30.0000         2
# 888         0       3    0  29.699118      1      2     675  23.4500         2
# 889         1       1    1  26.000000      0      0       8  30.0000         0
# 890         0       3    1  32.000000      0      0     466   7.7500         1
#
# [891 rows x 9 columns]

# %%
X = df.drop(columns=['Survived'])
y = df['Survived']

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_classification
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import D
50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8349 - loss: 0.3965 - val_accuracy: 0.8252 - val_loss: 0.4153
# Epoch 32/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8406 - loss: 0.3813 - val_accuracy: 0.8182 - val_loss: 0.4168
# Epoch 33/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8600 - loss: 0.3391 - val_accuracy: 0.8182 - val_loss: 0.4150
# Epoch 34/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8437 - loss: 0.3777 - val_accuracy: 0.8252 - val_loss: 0.4148
# Epoch 35/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8628 - loss: 0.3551 - val_accuracy: 0.8252 - val_loss: 0.4133
# Epoch 36/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8535 - loss: 0.3649 - val_accuracy: 0.8252 - val_loss: 0.4162
# Epoch 37/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8383 - loss: 0.4024 - val_accuracy: 0.8182 - val_loss: 0.4165
# Epoch 38/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8418 - loss: 0.3897 - val_accuracy: 0.8182 - val_loss: 0.4116
# Epoch 39/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8369 - loss: 0.4060 - val_accuracy: 0.8182 - val_loss: 0.4157
# Epoch 40/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8499 - loss: 0.3812 - val_accuracy: 0.8182 - val_loss: 0.4152
# Epoch 41/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8597 - loss: 0.3596 - val_accuracy: 0.8252 - val_loss: 0.4186
# Epoch 42/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8715 - loss: 0.3392 - val_accuracy: 0.8182 - val_loss: 0.4177
# Epoch 43/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8727 - loss: 0.3443 - val_accuracy: 0.8252 - val_loss: 0.4168
# Epoch 44/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8565 - loss: 0.3670 - val_accuracy: 0.8112 - val_loss: 0.4203
# Epoch 45/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8541 - loss: 0.3782 - val_accuracy: 0.8252 - val_loss: 0.4195
# Epoch 46/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8643 - loss: 0.3363 - val_accuracy: 0.8252 - val_loss: 0.4216
# Epoch 47/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8630 - loss: 0.3663 - val_accuracy: 0.8112 - val_loss: 0.4185
# Epoch 48/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8532 - loss: 0.3884 - val_accuracy: 0.8182 - val_loss: 0.4206
# Epoch 49/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8371 - loss: 0.3934 - val_accuracy: 0.8182 - val_loss: 0.4209
# Epoch 50/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8734 - loss: 0.3319 - val_accuracy: 0.8182 - val_loss: 0.4224
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8196 - loss: 0.4283
# Test Accuracy: 0.82

# %% [markdown]
# Пример хорошего графика

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
history = model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# Epoch 1/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8658 - loss: 0.3434 - val_accuracy: 0.8112 - val_loss: 0.4216
# Epoch 2/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8737 - loss: 0.3214 - val_accuracy: 0.8252 - val_loss: 0.4215
# Epoch 3/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8522 - loss: 0.3525 - val_accuracy: 0.8252 - val_loss: 0.4251
# Epoch 4/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8900 - loss: 0.3163 - val_accuracy: 0.8182 - val_loss: 0.4180
# Epoch 5/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8655 - loss: 0.3327 - val_accuracy: 0.8252 - val_loss: 0.4299
# Epoch 6/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8579 - loss: 0.3499 - val_accuracy: 0.8112 - val_loss: 0.4204
# Epoch 7/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8653 - loss: 0.3226 - val_accuracy: 0.8112 - val_loss: 0.4246
# Epoch 8/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8741 - loss: 0.3312 - val_accuracy: 0.8252 - val_loss: 0.4248
# Epoch 9/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8755 - loss: 0.3406 - val_accuracy: 0.8112 - val_loss: 0.4227
# Epoch 10/10
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8667 - loss: 0.3500 - val_accuracy: 0.8252 - val_loss: 0.4245

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'],
         label='Доля правильных ответов на обучающем наборе')
plt.plot(history.history['val_accuracy'],
         label='Доля правильных ответов на проверочном наборе')
plt.xlabel('Эпоха обучения')
plt.ylabel('Доля правильных ответов')
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'],
         label='Ошибка на обучающем наборе')
plt.plot(history.history['val_loss'],
         label='Ошибка на проверочном наборе')
plt.xlabel('Эпоха обучения')
plt.ylabel('Доля правильных ответов')
plt.legend()
plt.show()
